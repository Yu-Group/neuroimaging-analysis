# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from os.path import join as oj

import sys
sys.path.append('../src')

from skimage.io import imshow

from puncta import *
from util import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_dir = '/clusterfs/fiona/jpduncan/exllsm'
m5 = 'm5-6_Sample8/processed slice-tiff/slice-tiff_chroma_cleaned_rotated'

# %%
# %%time

m5_ch0 = read_vol(oj(data_dir, m5, 'ch0'), n_slices=1, first_slice=4000, verbose=True)
m5_ch1 = read_vol(oj(data_dir, m5, 'ch1'), n_slices=1, first_slice=4000, verbose=True)
m5_ch2 = read_vol(oj(data_dir, m5, 'ch2'), n_slices=1, first_slice=4000, verbose=True)
# Out:
# Reading 1 slices from /clusterfs/fiona/jpduncan/exllsm/m5-6_Sample8/processed slice-tiff/slice-tiff_chroma_cleaned_rotated/ch0, starting at 4000.tif
# 0it [00:04, ?it/s]
# Volume shape: (1, 39519, 12228)
# Reading 1 slices from /clusterfs/fiona/jpduncan/exllsm/m5-6_Sample8/processed slice-tiff/slice-tiff_chroma_cleaned_rotated/ch1, starting at 4000.tif
# 0it [00:04, ?it/s]
# Volume shape: (1, 39519, 12228)
# Reading 1 slices from /clusterfs/fiona/jpduncan/exllsm/m5-6_Sample8/processed slice-tiff/slice-tiff_chroma_cleaned_rotated/ch2, starting at 4000.tif
# 0it [00:04, ?it/s]
# Volume shape: (1, 39519, 12228)
# CPU times: user 7.86 s, sys: 5.62 s, total: 13.5 s
# Wall time: 13.5 s

# %%
plot_channels([m5_ch0[0,:,:], m5_ch1[0,:,:], m5_ch2[0,:,:]], figsize=(10, 15))
